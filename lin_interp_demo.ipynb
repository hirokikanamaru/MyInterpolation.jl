# %% [markdown]
# <br />
#
# <div style="text-align:center;">
# <font size = 7>Linear Interpolations 金丸博樹</font>
# </div>
# <br />

# %%
using MyInterpolations

# %% [markdown]
# <br />
#
# <div style="text-align:center;">
# <font size = 4>コードはこちら：https://github.com/hirokikanamaru/MyInterpolations.jl/blob/master/src/MyInterpolations.jl</font>
# </div>
# <br />

# %%
Pkg.test("MyInterpolations")
# Out:
# INFO: Testing MyInterpolations
# INFO: MyInterpolations tests passed

# %%
grid=[i for i in 1:20]
vals=[2,5,-2,7,9,11,22,24,26,30,28,26,25,18,16,12,9,7,4,-2];

# %%
f=my_lin_interp(grid,vals)
# Out:
# (::func) (generic function with 1 method)

# %%
f.([2.2,3.4,5.6,7.2,9.2])
# Out:
# 5-element Array{Float64,1}:
#   3.6
#   1.6
#  10.2
#  22.4
#  26.8

# %%
using Plots

x_grid=linspace(grid[1],grid[end], 1000)
y_vals=map(f, x_grid)
plot(x_grid, y_vals)
# Out:
# WARNING: using Plots.grid in module Main conflicts with an existing identifier.
# <img src="data:image/png;base64,..." />
